# %% [markdown]
# # you have a data set called shopping cart it consist of four datasets
# - 1- customers.csv
# - 2- orders.csv
# - 3- products.csv
# - 4- sales.csv
# # your task in this project is:
# - 1- combine this data together
# - 2- check messing values
# - 3- show summary statistics
# - 4- deal with date time and extract features from dates
# - 5- answer at least three questions from this data

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd

# %% [markdown]
# ### Load data

# %%
df=pd.read_csv('customers.csv')

# %%
df1=pd.read_csv('orders.csv')

# %%
df2=pd.read_csv('sales.csv')

# %%
df3=pd.read_csv('products.csv')

# %% [markdown]
# ### Merge the data

# %%
df.columns
# Out:
# Index(['customer_id', 'customer_name', 'gender', 'age', 'home_address',
#        'zip_code', 'city', 'state', 'country'],
#       dtype='object')

# %%
first_Merge = pd.merge(left=df2, right=df3, left_on='product_id', right_on='product_ID', how='inner')

# %%
second_Merge=pd.merge(left=df1, right=first_Merge,on='order_id', how='inner')

# %%
df=pd.merge(left=df,right=second_Merge,on='customer_id',how='inner')

# %%
df.head(1)
# Out:
#    customer_id  customer_name  gender  age                    home_address  \
# 0            1  Leanna Busson  Female   30  8606 Victoria TerraceSuite 560
#
#    zip_code           city               state    country  order_id  ...  \
# 0      5464  Johnstonhaven  Northern Territory  Australia       455  ...
#
#    quantity_x total_price product_ID  product_type  product_name  size  \
# 0           3         318        211         Shirt      Chambray     S
#
#    colour  price  quantity_y                              description
# 0     red    105          72  A red coloured, S sized, Chambray Shirt
#
# [1 rows x 26 columns]

# %% [markdown]
# ### EDA (Task)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customer_id     5000 non-null   int64
#  1   customer_name   5000 non-null   object
#  2   gender          5000 non-null   object
#  3   age             5000 non-null   int64
#  4   home_address    5000 non-null   object
#  5   zip_code        5000 non-null   int64
#  6   city            5000 non-null   object
#  7   state           5000 non-null   object
#  8   country         5000 non-null   object
#  9   order_id        5000 non-null   int64
#  10  payment         5000 non-null   int64
#  11  order_date      5000 non-null   object
#  12  delivery_date   5000 non-null   object
#  13  sales_id        5000 non-null   int64
#  14  product_id      5000 non-null   int64
#  15  price_per_unit  5000 non-null   int64
#  16  quantity_x      5000 non-null   int64
# ...

# %%
df.describe(include='O')
# Out:
#          customer_name  gender              home_address        city  \
# count             5000    5000                      5000        5000
# unique             616       8                       616         604
# top     Kristofor Roos  Female  5567 Clarke MallApt. 756  Jordanside
# freq                37     712                        37          37
#
#                   state    country order_date delivery_date product_type  \
# count              5000       5000       5000          5000         5000
# unique                8          1        291           304            3
# top     South Australia  Australia  2021-6-21    2021-03-28     Trousers
# freq                718       5000         51            49         1683
#
#        product_name  size colour                                description
# count          5000  5000   5000                                       5000
# unique           35     5      7                                       1233
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### what is the unique values in each categorical column

# %%
for col in df.columns:
    print(col,'\n')
    print(df[col].unique())
    print('---'*50)
# Out:
# customer_id
#
# [   1    7   10   11   12   13   15   16   18   19   20   21   22   23
#    25   26   27   28   34   35   40   41   42   44   45   46   47   49
#    50   51   52   54   55   58   60   61   62   64   68   69   70   72
#    73   75   76   77   78   79   81   83   84   85   86   87   88   89
#    92   93   94   95   96   97   99  100  102  103  104  106  107  108
#   110  111  112  113  116  117  118  120  123  124  125  127  128  129
#   133  134  135  139  142  144  146  148  150  155  156  158  160  161
#   163  167  169  171  176  178  179  180  181  183  185  187  189  191
#   192  195  196  198  199  201  203  204  206  207  208  209  211  212
#   214  218  219  221  223  224  225  227  228  230  232  233  234  236
#   237  238  239  240  241  244  246  247  250  251  254  256  257  258
#   260  263  264  265  266  267  268  269  272  273  276  278  282  283
#   286  288  289  290  291  292  298  299  300  301  303  305  306  308
# ...

# %% [markdown]
# ### convert to datetime format

# %%
df['delivery_date']=pd.to_datetime(df['delivery_date'])

# %%
df['order_date']=pd.to_datetime(df['order_date'])

# %%
df['delivery_date'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 5000 entries, 0 to 4999
# Series name: delivery_date
# Non-Null Count  Dtype
# --------------  -----
# 5000 non-null   datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 39.2 KB

# %%
df['order_date'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 5000 entries, 0 to 4999
# Series name: order_date
# Non-Null Count  Dtype
# --------------  -----
# 5000 non-null   datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 39.2 KB

# %% [markdown]
# ### what is the maximum number of days between the order and delivery

# %%
(df['delivery_date'] - df['order_date']).dt.days.max()
# Out:
# 27

# %% [markdown]
# ### extract year , month and day name for order data

# %%
df['year'] = df['order_date'].dt.year
df['month'] = df['order_date'].dt.month
df['day_name'] = df['order_date'].dt.day_name()

# %%
df[['year','month','day_name']]
# Out:
#       year  month  day_name
# 0     2021      4    Sunday
# 1     2021      4    Sunday
# 2     2021      3  Saturday
# 3     2021      3  Saturday
# 4     2021      3  Saturday
# ...    ...    ...       ...
# 4995  2021     10    Monday
# 4996  2021     10    Monday
# 4997  2021     10    Monday
# 4998  2021     10    Monday
# 4999  2021     10    Monday
#
# [5000 rows x 3 columns]

# %% [markdown]
# ### extract year , month and day name for delivery data

# %%
df['year'] = df['delivery_date'].dt.year
df['month'] = df['delivery_date'].dt.month
df['day_name'] = df['delivery_date'].dt.day_name()

# %%
df[['year','month','day_name']]
# Out:
#       year  month   day_name
# 0     2021      4    Tuesday
# 1     2021      4    Tuesday
# 2     2021      4   Thursday
# 3     2021      4   Thursday
# 4     2021      4   Thursday
# ...    ...    ...        ...
# 4995  2021     10  Wednesday
# 4996  2021     10  Wednesday
# 4997  2021     10  Wednesday
# 4998  2021     10  Wednesday
# 4999  2021     10  Wednesday
#
# [5000 rows x 3 columns]

# %% [markdown]
# ### what is the most day that get highest income

# %%
df['income']=df['price'] * df['quantity_y']
df['day'] = df['order_date'].dt.day

# %%
df.groupby('income')['day'].max().to_frame().head(1)
# Out:
#         day
# income
# 3600     30

# %% [markdown]
# ### what is the total money that each gendre spent

# %%
df.groupby('gender')['income'].sum()
# Out:
# gender
# Agender        3311787
# Bigender       3295320
# Female         4504785
# Genderfluid    4369223
# Genderqueer    4148999
# Male           4269541
# Non-binary     3846313
# Polygender     4043118
# Name: income, dtype: int64

# %%
df['gender'].unique()
# Out:
# array(['Female', 'Bigender', 'Agender', 'Male', 'Genderfluid',
#        'Genderqueer', 'Non-binary', 'Polygender'], dtype=object)

# %% [markdown]
# ### what is the highest month that get the highest sales?

# %%
df.groupby('month')['quantity_y'].sum().to_frame().head(1)
# Out:
#        quantity_y
# month
# 1           18260

# %% [markdown]
# ### what is the highest state achieve the highest salees

# %%
df.groupby('state')['quantity_y'].sum().to_frame().head(1)
# Out:
#                               quantity_y
# state
# Australian Capital Territory       38337

# %% [markdown]
# ### what is the highest state per gender achieve the highest sales

# %%
df.groupby(['state', 'gender'])['quantity_y'].sum().to_frame().head(1)
# Out:
#                                       quantity_y
# state                        gender
# Australian Capital Territory Agender        6907

# %% [markdown]
# ### what is the average age per state

# %%
df.groupby('state')['price'].mean().to_frame()
# Out:
#                                    price
# state
# Australian Capital Territory  105.485893
# New South Wales               105.978362
# Northern Territory            105.973535
# Queensland                    106.014556
# South Australia               105.221448
# Tasmania                      105.977816
# Victoria                      105.262267
# Western Australia             105.471854

# %% [markdown]
# ### what is the average age per state per each gender

# %%
df.groupby(['state', 'gender'])['price'].mean().to_frame()
# Out:
#                                                price
# state                        gender
# Australian Capital Territory Agender      105.974138
#                              Bigender     105.754098
#                              Female       104.583333
#                              Genderfluid  104.915094
#                              Genderqueer  105.325581
# ...                                              ...
# Western Australia            Genderfluid  105.047059
#                              Genderqueer  106.964286
#                              Male         105.769231
#                              Non-binary   104.132075
#                              Polygender   105.666667
#
# [64 rows x 1 columns]

# %% [markdown]
# ### what is the product type that have the highest sales

# %%
df.groupby('product_type')['quantity_y'].sum().head(1)
# Out:
# product_type
# Jacket    101407
# Name: quantity_y, dtype: int64

# %% [markdown]
# ### what is the color of the product type that have highest sales?

# %%
df.groupby(['product_type','colour'])['quantity_y'].sum().head(1)
# Out:
# product_type  colour
# Jacket        blue      15408
# Name: quantity_y, dtype: int64

# %% [markdown]
# ### No pain no gain                  : )
